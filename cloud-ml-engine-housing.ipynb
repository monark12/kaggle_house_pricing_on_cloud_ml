# %% [markdown]
# # Submitting Training jobs to Google Cloud ML Engine and Serving that model for predictions

# %% [markdown]
# The notebook goes through step by step process to create, train and deploy your custom estimator models to [Google Cloud ML-Engine](https://cloud.google.com/ml-engine/)

# %% [markdown]
# # Submitting Training Jobs
# ## Part 0 --> Getting the data
# The dataset I am using is Kaggle's House Price Prediction dataset. You can download the dataset from [here](https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data)
#
# ## Have a look at the data and the preprocessing steps
# The data file is currently located in my local disk, so I'll be using that for demonstrating the steps. The steps that I show here will be used while creating the python package

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, PowerTransformer
path = 'kaggle_housing_prices.csv'

df_train = pd.read_csv(path)
df_train = df_train[df_train.columns.difference(['Id'])]
df_train = df_train.fillna(0)
df_train = pd.get_dummies(df_train)

X = df_train[df_train.columns.difference(['SalePrice'])].values
y = df_train[['SalePrice']].values

pt_X = PowerTransformer(method='yeo-johnson', standardize=False)
sc_y = StandardScaler()
sc_X = StandardScaler()
y = sc_y.fit_transform(y)
X = sc_X.fit_transform(X)

print(X[:5], X.shape)
print()
print(y[:5], y.shape)
# Out:
# [[-0.79343379  1.16185159 -0.11633929 ...  1.05099379  0.87866809
#    0.13877749]
#  [ 0.25714043 -0.79516323 -0.11633929 ...  0.15673371 -0.42957697
#   -0.61443862]
#  [-0.62782603  1.18935062 -0.11633929 ...  0.9847523   0.83021457
#    0.13877749]
#  [-0.52173356  0.93727612 -0.11633929 ... -1.86363165 -0.72029809
#   -1.36765473]
#  [-0.04561126  1.61787729 -0.11633929 ...  0.95163156  0.73330753
#    0.13877749]] (1460, 304)
#
# [[ 0.34727322]
#  [ 0.00728832]
#  [ 0.53615372]
#  [-0.51528106]
#  [ 0.8698426 ]] (1460, 1)
# /Users/monarkunadkat/miniconda3/envs/p36/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/monarkunadkat/miniconda3/envs/p36/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# ## Part 1 --> Creating The Python Package
# The file structure of your python package will look like this

# %%
# !tree trainer/
# Out:
# trainer/
# ├── __init__.py
# ├── model.py
# └── task.py
#
# 0 directories, 3 files

# %% [markdown]
# 1. model.py will contain functions defining your model architecture, input function and serving input function. (Mandatory)
# 2. task.py is where you define your hyperparameters, estimator specs, data preprocessing steps and all other necessary functions required to create the dataset. It is optional to create this file, but it keeps the code clean and manageable. (Optional)

# %% [markdown]
# ## model.py
# In this file, minimum of 3 functions are needed to be defined. They are -->
# 1. model_fn() or keras_estimator(). For the sake of this example, I am using keras_estimator(). the function will return estimator instance of your compiled keras model.
# 2. input_fn() which is used for passing input to your model. it returns a dataset iterator object.
# 3. serving_input_fn() defines the features to be passed to the model during inference, for ex-> TensorServingInputReceiver object

# %%
# %cat trainer/model.py
# Out:
# import tensorflow as tf
# from tensorflow.keras.layers import Dense
# from tensorflow.python.keras import models
# from tensorflow.keras.optimizers import Adam
# tf.logging.set_verbosity(tf.logging.INFO)
#
# def keras_estimator(model_dir, config, params):
#     model = models.Sequential()
#     model.add(Dense(units=480, kernel_initializer='random_uniform', activation= 'relu',
#     			input_shape=(params['num_features'],)))
#     model.add(Dense(units=480, kernel_initializer='random_uniform', activation= 'relu'))
#     model.add(Dense(units=10, kernel_initializer='random_uniform', activation= 'relu'))
#     model.add(Dense(units=1, kernel_initializer='random_uniform', activation= 'elu'))
#     optimizer = Adam(lr=0.0015, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
#     model.compile(optimizer=optimizer, loss='mean_squared_logarithmic_error', metrics=['mse'])
#     print('####', type(tf.k))
#     return tf.keras.estimator.model_to_estimator(keras_model=model, model_dir=model_dir,
#     												config=config)
#
# def input_fn(features, labels, batch_size, mode):
# 	if labels is None:
# 		inputs = features
# 	else:
# 		inputs = (features, labels)
# 	dataset = tf.data.Dataset.from_tensor_slices(inputs)
# 	if mode == tf.estimator.ModeKeys.TRAIN:
# 		dataset = dataset.shuffle(1000).repeat().batch(batch_size)
# 	if mode in (tf.estimator.ModeKeys.EVAL, tf.estimator.ModeKeys.PREDICT):
# 		dataset = dataset.batch(batch_size)
# 	return dataset.make_one_shot_iterator().get_next()
#
# def serving_input_fn():
# 	feature_placeholder = tf.placeholder(tf.float32, [None, 304])
# 	features = feature_placeholder
# 	return tf.estimator.export.TensorServingInputReceiver(features, feature_placeholder)

# %% [markdown]
# ## task.py
# 1. Reads and parses model parameters, like location of the training data and output model, # hidden layers, batch size, etc.
# 2. loads data from the location specified and applies preprocessing logic.
# 3. Calls the model training logic located in model.py with said parameters.

# %%
# %cat trainer/task.py
# Out:
# import argparse
# from . import model
# import numpy as np
# import tensorflow as tf
# import os
# import subprocess
# from sklearn.preprocessing import PowerTransformer, StandardScaler
# import pandas as pd
#
#
# WORKING_DIR = os.getcwd()
# TEMP_DIR = 'tmp/'
# DATA_FILE_NAME = 'kaggle_housing_prices.csv'
#
#
# def download_files_from_gcs(source, destination):
#     local_file_names = [destination]
#     gcs_input_paths = [source]
#
#     raw_local_files_data_paths = [os.path.join(WORKING_DIR, local_file_name) for local_file_name in local_file_names]
#     for i, gcs_input_path in enumerate(gcs_input_paths):
#         if gcs_input_path:
#             subprocess.check_call(['gsutil', 'cp', gcs_input_path, raw_local_files_data_paths[i]])
#
#     return raw_local_files_data_paths
#
#
# def load_data(path='kaggle_housing_prices.csv', test_split=0.2, seed=113):
#     assert 0 <= test_split < 1
#     if not path:
#         raise ValueError('No dataset file defined')
#
#     if path.startswith('gs://'):
#         download_files_from_gcs(path, destination=DATA_FILE_NAME)
#         path = DATA_FILE_NAME
#
#     df_train = pd.read_csv(path)
#     df_train = df_train[df_train.columns.difference(['Id'])]
#     df_train = df_train.fillna(0)
#     df_train = pd.get_dummies(df_train)
#     X = df_train[df_train.columns.difference(['SalePrice'])].values
#     y = df_train[['SalePrice']].values
#     pt_X = PowerTransformer(method='yeo-johnson', standardize=False)
#     sc_y = StandardScaler()
#     sc_X = StandardScaler()
#     y = sc_y.fit_transform(y)
#     X = sc_X.fit_transform(X)
#
#     indices = np.arange(len(X))
#     np.random.shuffle(indices)
#     X = X[indices]
#     y = y[indices]
#
#     x_train = np.array(X[:int(len(X) * (1 - test_split))])
#     y_train = np.array(y[:int(len(X) * (1 - test_split))])
#     x_test = np.array(X[int(len(X) * (1 - test_split)):])
#     y_test = np.array(y[int(len(X) * (1 - test_split)):])
#     return (x_train, y_train), (x_test, y_test)
# def get_args():
#     parser = argparse.ArgumentParser()
#     parser.add_argument(
#     	'--job-dir',
#     	type=str,
#     	help='GCS location to write checkpoints and export models')
#     parser.add_argument(
#     	'--train-file',
#     	type=str,
#     	required=True,
#     	help='Dataset file local or GCS')
#     parser.add_argument(
#     	'--test-split',
#     	type=float,
#     	default=0.2,
#     	help='Split between training and test, default=0.2')
#     parser.add_argument(
#     	'--num-epochs',
#     	type=float,
#     	default=500,
#     	help='number of times to go through the data, default=500')
#     parser.add_argument(
#     	'--batch-size',
#     	type=int,
#     	default=128,
#     	help='number of records to read during each training step, default=128')
#     parser.add_argument(
#     	'--learning-rate',
#     	type=float,
#     	default=.001,
#     	help='learning rate for gradient descent, default=.001')
#     parser.add_argument(
#     	'--verbosity',
#     	choices=['DEBUG', 'ERROR', 'FATAL', 'INFO', 'WARN'],
#     	default='INFO')
#     args, _ = parser.parse_known_args()
#     return args
#
# def train_and_evaluate(args):
#     (train_data,train_labels), (test_data,test_labels) = load_data(path=args.train_file)
#     run_config = tf.estimator.RunConfig(save_checkpoints_steps=500)
#     train_steps = args.num_epochs * len(train_data) / args.batch_size
#     train_labels = np.asarray(train_labels).astype('float32').reshape((-1, 1))
#     train_spec = tf.estimator.TrainSpec(
#     	input_fn=lambda: model.input_fn(
#     		train_data,
#     		train_labels,
#     		args.batch_size,
#     		mode=tf.estimator.ModeKeys.TRAIN),
#     	max_steps=train_steps)
#     exporter = tf.estimator.LatestExporter('exporter', model.serving_input_fn)
#     test_labels = np.asarray(test_labels).astype('float32').reshape((-1, 1))
#     eval_spec = tf.estimator.EvalSpec(
#     	input_fn=lambda: model.input_fn(
#     		test_data,
#     		test_labels,
#     		args.batch_size,
#     		mode=tf.estimator.ModeKeys.EVAL),
#     	steps=None,
#     	exporters=[exporter],
#     	start_delay_secs=10,
#     	throttle_secs=10)
#     estimator = model.keras_estimator(
#     	model_dir=args.job_dir,
#     	config=run_config,
#     	params={'learning_rate': args.learning_rate,'num_features': train_data.shape[1]})
#     tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)
#
# if __name__ == '__main__':
#     args = get_args()
#     tf.logging.set_verbosity(args.verbosity)
#     train_and_evaluate(args)

# %% [markdown]
# ## setup.py
# There is one more file you need to have if you are using some python libraries which are not a part of standard library. The file is setup.py. In our case, we need a specific verison of scikit-learn, so we will define that in the setup.py file.A setup.py configuration file will look like this

# %%
# %cat setup.py
# Out:
# from setuptools import find_packages
# from setuptools import setup
#
# REQUIRED_PACKAGES = [
#   'scikit-learn==0.20.1',
# ]
#
# setup(
#     name='trainer',
#     version='0.1',
#     install_requires=REQUIRED_PACKAGES,
#     packages=find_packages(),
#     include_package_data=True,
#     requires=[]
# )

# %% [markdown]
# ## Part 2 --> Training
# You have 2 options for training your model. Either you train it locally or you can create a training job on cloud-ml engine. I will demonstrate both
#
# ### 1. Training locally

# %%
#Define some environment variable for our training job
# %env JOB_DIR house_pricing_training_job/
# !rm -rf $JOB_DIR
# %env TRAIN_FILE kaggle_housing_prices.csv
# Out:
# env: JOB_DIR=house_pricing_training_job/
# env: TRAIN_FILE=kaggle_housing_prices.csv

# %%
#Starting the local training job
# !gcloud ml-engine local train --module-name=trainer.task \
 --package-path=trainer \
 --train-file=$TRAIN_FILE \
 --job-dir=$JOB_DIR
# Out:
# /Users/monarkunadkat/miniconda3/envs/p36/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/monarkunadkat/miniconda3/envs/p36/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# INFO:tensorflow:TF_CONFIG environment variable: {'environment': 'cloud', 'cluster': {}, 'job': {'args': ['--train-file=kaggle_housing_prices.csv', '--job-dir=house_pricing_training_job/'], 'job_name': 'trainer.task'}, 'task': {}}
# INFO:tensorflow:Using the Keras model provided.
# 2018-12-27 15:12:17.641337: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2018-12-27 15:12:17.641633: I tensorflow/core/common_runtime/process_util.cc:69] Creating new thread pool with default inter op setting: 4. Tune using inter_op_parallelism_threads for best performance.
# INFO:tensorflow:Using config: {'_model_dir': 'house_pricing_training_job/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 500, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x129d59d68>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps 500 or save_checkpoints_secs None.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='house_pricing_training_job/keras/keras_model.ckpt', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: ('house_pricing_training_job/keras/keras_model.ckpt',)
# INFO:tensorflow:Warm-starting variable: dense/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_2/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_2/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_3/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: dense_3/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: Adam/iterations; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: Adam/lr; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: Adam/beta_1; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: Adam/beta_2; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: Adam/decay; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: training/Adam/Variable; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: training/Adam/Variable_1; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: training/Adam/Variable_2; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: training/Adam/Variable_3; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: training/Adam/Variable_4; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: training/Adam/Variable_5; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: training/Adam/Variable_6; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: training/Adam/Variable_7; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: training/Adam/Variable_8; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: training/Adam/Variable_9; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: training/Adam/Variable_10; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: training/Adam/Variable_11; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: training/Adam/Variable_12; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: training/Adam/Variable_13; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: training/Adam/Variable_14; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: training/Adam/Variable_15; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: training/Adam/Variable_16; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: training/Adam/Variable_17; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: training/Adam/Variable_18; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: training/Adam/Variable_19; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: training/Adam/Variable_20; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: training/Adam/Variable_21; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: training/Adam/Variable_22; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: training/Adam/Variable_23; prev_var_name: Unchanged
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into house_pricing_training_job/model.ckpt.
# INFO:tensorflow:loss = 0.19852936, step = 1
# INFO:tensorflow:global_step/sec: 20.2649
# INFO:tensorflow:loss = 0.0028986465, step = 101 (4.935 sec)
# INFO:tensorflow:global_step/sec: 39.8198
# INFO:tensorflow:loss = 0.0010061173, step = 201 (2.511 sec)
# INFO:tensorflow:global_step/sec: 45.0258
# INFO:tensorflow:loss = 0.0006789453, step = 301 (2.221 sec)
# INFO:tensorflow:global_step/sec: 44.8751
# INFO:tensorflow:loss = 0.00070749415, step = 401 (2.228 sec)
# INFO:tensorflow:Saving checkpoints for 500 into house_pricing_training_job/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-27-09:42:38
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from house_pricing_training_job/model.ckpt-500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-27-09:42:39
# INFO:tensorflow:Saving dict for global step 500: global_step = 500, loss = 0.070608445, mse = 1.0965357
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 500: house_pricing_training_job/model.ckpt-500
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from house_pricing_training_job/model.ckpt-500
# WARNING:tensorflow:From /Users/monarkunadkat/miniconda3/envs/p36/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py:1044: calling SavedModelBuilder.add_meta_graph_and_variables (from tensorflow.python.saved_model.builder_impl) with legacy_init_op is deprecated and will be removed in a future version.
# Instructions for updating:
# Pass your op to the equivalent parameter main_op instead.
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: house_pricing_training_job/export/exporter/temp-b'1545903759'/saved_model.pb
# INFO:tensorflow:global_step/sec: 26.2791
# INFO:tensorflow:loss = 0.00061364105, step = 501 (3.806 sec)
# INFO:tensorflow:global_step/sec: 44.0313
# INFO:tensorflow:loss = 0.00054410036, step = 601 (2.271 sec)
# INFO:tensorflow:global_step/sec: 45.518
# INFO:tensorflow:loss = 0.00043586182, step = 701 (2.197 sec)
# INFO:tensorflow:global_step/sec: 46.0551
# INFO:tensorflow:loss = 0.00010561759, step = 801 (2.171 sec)
# INFO:tensorflow:global_step/sec: 46.5945
# INFO:tensorflow:loss = 0.00031923706, step = 901 (2.146 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into house_pricing_training_job/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-27-09:42:51
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from house_pricing_training_job/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-27-09:42:51
# INFO:tensorflow:Saving dict for global step 1000: global_step = 1000, loss = 0.06677695, mse = 1.0211835
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: house_pricing_training_job/model.ckpt-1000
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from house_pricing_training_job/model.ckpt-1000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to
secs).
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-27-09:44:21
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from house_pricing_training_job/model.ckpt-4563
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-27-09:44:22
# INFO:tensorflow:Saving dict for global step 4563: global_step = 4563, loss = 0.06863203, mse = 0.9775153
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4563: house_pricing_training_job/model.ckpt-4563
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from house_pricing_training_job/model.ckpt-4563
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: house_pricing_training_job/export/exporter/temp-b'1545903862'/saved_model.pb
# INFO:tensorflow:Loss for final step: 9.165338e-05.

# %% [markdown]
# When the job finishes, it will create a directory named house_pricing_training_job which we previously defined as our JOB_DIR. The directory will contain your model checkpoint, graph signature and tensorflow SavedModel which will be written to JOB_DIR/export/exporter/.
# If you want to check the model spec and model signature definition, you can navigate to that directory and use saved_model_cli. You can refer this [blog](https://medium.com/@yuu.ishikawa/how-to-show-signatures-of-tensorflow-saved-model-5ac56cf1960f) to know how to install that.
#
# The cell below demonstrates the same thing.

# %%
# %cd house_pricing_training_job/export/exporter/1545903862/
# !saved_model_cli show --dir ./ --all
# Out:
# /Users/monarkunadkat/Desktop/Searce/cloudml-samples/boston/tensorflow/keras/house_pricing_training_job/export/exporter/1545903862
#
# MetaGraphDef with tag-set: 'serve' contains the following SignatureDefs:
#
# signature_def['serving_default']:
#   The given SavedModel SignatureDef contains the following input(s):
#     inputs['input'] tensor_info:
#         dtype: DT_FLOAT
#         shape: (-1, 304)
#         name: Placeholder:0
#   The given SavedModel SignatureDef contains the following output(s):
#     outputs['dense_3'] tensor_info:
#         dtype: DT_FLOAT
#         shape: (-1, 1)
#         name: dense_3/Elu:0
#   Method name is: tensorflow/serving/predict

# %% [markdown]
# Similarly you can submit a training job to cloud ml-engine. To do that, you will first need to upload your training file to GCS
#
# ### 2. Training on Google Cloud ML-Engine

# %%
# !gsutil cp kaggle_housing_prices.csv gs://cloud-ml-data-storage-bucket
# Out:
# Copying file://kaggle_housing_prices.csv [Content-Type=text/csv]...
# \ [1 files][449.9 KiB/449.9 KiB]
# Operation completed over 1 objects/449.9 KiB.

# %%
#Defining Environment Variable
# %env JOB_NAME housing_job_3
# %env GCS_JOB_DIR gs://cloud-ml-job-bucket
# %env TRAIN_FILE gs://cloud-ml-data-storage-bucket/kaggle_housing_prices.csv
# %env REGION us-central1
# Out:
# env: JOB_NAME=housing_job_3
# env: GCS_JOB_DIR=gs://cloud-ml-job-bucket
# env: TRAIN_FILE=gs://cloud-ml-data-storage-bucket/kaggle_housing_prices.csv
# env: REGION=us-central1

# %% [markdown]
# As soon as you run the below command, a training job will be submitted to cloud ml-engine. you can see the logs in the terminal itself or you can login to your Google Cloud console to see the logs.

# %%
#Run in Google Cloud ML Engine:
# !gcloud ml-engine jobs submit training $JOB_NAME \
 --stream-logs \
 --runtime-version 1.10 \
 --job-dir=$GCS_JOB_DIR \
 --package-path=trainer \
 --module-name trainer.task \
 --region $REGION -- \
 --train-file=$TRAIN_FILE
# Out:
# Job [housing_job_3] submitted successfully.
# INFO	2018-12-27 15:35:06 +0530	service		Validating job requirements...
# INFO	2018-12-27 15:35:06 +0530	service		Job creation request has been successfully validated.
# INFO	2018-12-27 15:35:07 +0530	service		Job housing_job_3 is queued.
# INFO	2018-12-27 15:35:07 +0530	service		Waiting for job to be provisioned.
# INFO	2018-12-27 15:35:13 +0530	service		Waiting for training program to start.
# INFO	2018-12-27 15:36:05 +0530	master-replica-0		Running task with arguments: --cluster={"master": ["127.0.0.1:2222"]} --task={"type": "master", "index": 0} --job={  "package_uris": ["gs://cloud-ml-job-bucket/packages/d1c80a5dcb380377a509f9f22b9343fb946a7860a34a4ab508c59738a85d2dec/trainer-0.1.tar.gz"],  "python_module": "trainer.task",  "args": ["--train-file\u003dgs://cloud-ml-data-storage-bucket/kaggle_housing_prices.csv"],  "region": "us-central1",  "runtime_version": "1.10",  "job_dir": "gs://cloud-ml-job-bucket/",  "run_on_raw_vm": true}
# INFO	2018-12-27 15:36:13 +0530	master-replica-0		Running module trainer.task.
# INFO	2018-12-27 15:36:13 +0530	master-replica-0		Downloading the package: gs://cloud-ml-job-bucket/packages/d1c80a5dcb380377a509f9f22b9343fb946a7860a34a4ab508c59738a85d2dec/trainer-0.1.tar.gz
# INFO	2018-12-27 15:36:13 +0530	master-replica-0		Running command: gsutil -q cp gs://cloud-ml-job-bucket/packages/d1c80a5dcb380377a509f9f22b9343fb946a7860a34a4ab508c59738a85d2dec/trainer-0.1.tar.gz trainer-0.1.tar.gz
# INFO	2018-12-27 15:36:16 +0530	master-replica-0		Installing the package: gs://cloud-ml-job-bucket/packages/d1c80a5dcb380377a509f9f22b9343fb946a7860a34a4ab508c59738a85d2dec/trainer-0.1.tar.gz
# INFO	2018-12-27 15:36:16 +0530	master-replica-0		Running command: pip install --user --upgrade --force-reinstall --no-deps trainer-0.1.tar.gz
# INFO	2018-12-27 15:36:25 +0530	master-replica-0		Processing ./trainer-0.1.tar.gz
# INFO	2018-12-27 15:36:26 +0530	master-replica-0		Building wheels for collected packages: trainer
# INFO	2018-12-27 15:36:26 +0530	master-replica-0		  Running setup.py bdist_wheel for trainer: started
# INFO	2018-12-27 15:36:26 +0530	master-replica-0		  Running setup.py bdist_wheel for trainer: finished with status 'done'
# INFO	2018-12-27 15:36:26 +0530	master-replica-0		  Stored in directory: /root/.cache/pip/wheels/e8/0c/c7/b77d64796dbbac82503870c4881d606fa27e63942e07c75f0e
# INFO	2018-12-27 15:36:26 +0530	master-replica-0		Successfully built trainer
# INFO	2018-12-27 15:36:26 +0530	master-replica-0		Installing collected packages: trainer
# INFO	2018-12-27 15:36:27 +0530	master-replica-0		Successfully installed trainer-0.1
# INFO	2018-12-27 15:36:27 +0530	master-replica-0		Running command: pip install --user trainer-0.1.tar.gz
# INFO	2018-12-27 15:36:27 +0530	master-replica-0		Processing ./trainer-0.1.tar.gz
# INFO	2018-12-27 15:36:28 +0530	master-replica-0		Collecting scikit-learn==0.20.1 (from trainer==0.1)
# INFO	2018-12-27 15:36:28 +0530	master-replica-0		  Downloading https://files.pythonhosted.org/packages/93/5f/a7b89db4915ad20f25dde7c36e9cbc8fc6adb4a1ef65a999ef1ffc379316/scikit_learn-0.20.1-cp27-cp27mu-manylinux1_x86_64.whl (5.5MB)
# INFO	2018-12-27 15:36:29 +0530	master-replica-0		Requirement already satisfied: scipy>=0.13.3 in /usr/local/lib/python2.7/dist-packages (from scikit-learn==0.20.1->trainer==0.1) (1.1.0)
# INFO	2018-12-27 15:36:29 +0530	master-replica-0		Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python2.7/dist-packages (from scikit-learn==0.20.1->trainer==0.1) (1.14.5)
# INFO	2018-12-27 15:36:29 +0530	master-replica-0		Building wheels for collected packages: trainer
# INFO	2018-12-27 15:36:29 +0530	master-replica-0		  Running setup.py bdist_wheel for trainer: started
# INFO	2018-12-27 15:36:29 +0530	master-replica-0		  Running setup.py bdist_wheel for trainer: finished with status 'done'
# INFO	2018-12-27 15:36:29 +0530	master-replica-0		  Stored in directory: /root/.cache/pip/wheels/e8/0c/c7/b77d64796dbbac82503870c4881d606fa27e63942e07c75f0e
# INFO	2018-12-27 15:36:29 +0530	master-replica-0		Successfully built trainer
# INFO	2018-12-27 15:36:30 +0530	master-replica-0		Installing collected packages: scikit-learn, trainer
# INFO	2018-12-27 15:36:31 +0530	master-replica-0		  Found existing installation: trainer 0.1
# INFO	2018-12-27 15:36:31 +0530	master-replica-0		    Uninstalling trainer-0.1:
# INFO	2018-12-27 15:36:31 +0530	master-replica-0		      Successfully uninstalled trainer-0.1
# INFO	2018-12-27 15:36:31 +0530	master-replica-0		Successfully installed scikit-learn-0.20.1 trainer-0.1
# INFO	2018-12-27 15:36:31 +0530	master-replica-0		Running command: python -m trainer.task --train-file=gs://cloud-ml-data-storage-bucket/kaggle_housing_prices.csv --job-dir gs://cloud-ml-job-bucket/
# ERROR	2018-12-27 15:36:35 +0530	master-replica-0		Copying gs://cloud-ml-data-storage-bucket/kaggle_housing_prices.csv...
# ERROR	2018-12-27 15:36:35 +0530	master-replica-0		/ [0 files][    0.0 B/449.9 KiB]
# ERROR	2018-12-27 15:36:35 +0530	master-replica-0		/ [1 files][449.9 KiB/449.9 KiB]
# ERROR	2018-12-27 15:36:35 +0530	master-replica-0		Operation completed over 1 objects/449.9 KiB.
# ERROR	2018-12-27 15:36:36 +0530	master-replica-0		/root/.local/lib/python2.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
# ERROR	2018-12-27 15:36:36 +0530	master-replica-0		  warnings.warn(msg, DataConversionWarning)
# INFO	2018-12-27 15:36:36 +0530	master-replica-0		TF_CONFIG environment variable: {u'environment': u'cloud', u'cluster': {u'master': [u'127.0.0.1:2222']}, u'job': {u'python_module': u'trainer.task', u'region': u'us-central1', u'args': [u'--train-file=gs://cloud-ml-data-storage-bucket/kaggle_housing_prices.csv', u'--job-dir', u'gs://cloud-ml-job-bucket/'], u'job_dir': u'gs://cloud-ml-job-bucket/', u'runtime_version': u'1.10', u'package_uris': [u'gs://cloud-ml-job-bucket/packages/d1c80a5dcb380377a509f9f22b9343fb946a7860a34a4ab508c59738a85d2dec/trainer-0.1.tar.gz'], u'run_on_raw_vm': True}, u'task': {u'index': 0, u'type': u'master', u'cloud': u'bf067b8e92a245402-ml'}}
# INFO	2018-12-27 15:36:36 +0530	master-replica-0		Using the Keras model provided.
# INFO	2018-12-27 15:36:36 +0530	master-replica-0		Using config: {'_save_checkpoints_secs': None, '_session_config': device_filters: "/job:ps"
# INFO	2018-12-27 15:36:36 +0530	master-replica-0		device_filters: "/job:master"
# INFO	2018-12-27 15:36:36 +0530	master-replica-0		allow_soft_placement: true
# INFO	2018-12-27 15:36:36 +0530	master-replica-0		graph_options {
# INFO	2018-12-27 15:36:36 +0530	master-replica-0		  rewrite_options {
# INFO	2018-12-27 15:36:36 +0530	master-replica-0		    meta_optimizer_iterations: ONE
# INFO	2018-12-27 15:36:36 +0530	master-replica-0		  }
# INFO	2018-12-27 15:36:36 +0530	master-replica-0		}
# INFO	2018-12-27 15:36:36 +0530	master-replica-0		, '_keep_checkpoint_max': 5, '_task_type': u'master', '_global_id_in_cluster': 0, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f44f56e7190>, '_evaluation_master': '', '_save_checkpoints_steps': 500, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_device_fn': None, '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': 'gs://cloud-ml-job-bucket/', '_train_distribute': None, '_save_summary_steps': 100}
# INFO	2018-12-27 15:36:40 +0530	master-replica-0		Skip starting Tensorflow server as there is only one node in the cluster.
# INFO	2018-12-27 15:36:41 +0530	master-replica-0		Calling model_fn.
# INFO	2018-12-27 15
into gs://cloud-ml-job-bucket/model.ckpt.
# INFO	2018-12-27 15:37:19 +0530	master-replica-0		Calling model_fn.
# INFO	2018-12-27 15:37:19 +0530	master-replica-0		Done calling model_fn.
# INFO	2018-12-27 15:37:19 +0530	master-replica-0		Starting evaluation at 2018-12-27-10:07:19
# INFO	2018-12-27 15:37:19 +0530	master-replica-0		Graph was finalized.
# INFO	2018-12-27 15:37:19 +0530	master-replica-0		Restoring parameters from gs://cloud-ml-job-bucket/model.ckpt-1000
# INFO	2018-12-27 15:37:20 +0530	master-replica-0		Running local_init_op.
# INFO	2018-12-27 15:37:20 +0530	master-replica-0		Done running local_init_op.
# INFO	2018-12-27 15:37:20 +0530	master-replica-0		Finished evaluation at 2018-12-27-10:07:20
# INFO	2018-12-27 15:37:20 +0530	master-replica-0		Saving dict for global step 1000: global_step = 1000, loss = 0.1984755, mse = 1.9340057
# INFO	2018-12-27 15:37:20 +0530	master-replica-0		Saving 'checkpoint_path' summary for global step 1000: gs://cloud-ml-job-bucket/model.ckpt-1000
# INFO	2018-12-27 15:37:21 +0530	master-replica-0		Calling model_fn.
# INFO	2018-12-27 15:37:22 +0530	master-replica-0		Done calling model_fn.
# INFO	2018-12-27 15:37:22 +0530	master-replica-0		Signatures INCLUDED in export for Eval: None
# INFO	2018-12-27 15:37:22 +0530	master-replica-0		Signatures INCLUDED in export for Classify: None
# INFO	2018-12-27 15:37:22 +0530	master-replica-0		Signatures INCLUDED in export for Regress: None
# INFO	2018-12-27 15:37:22 +0530	master-replica-0		Signatures INCLUDED in export for Predict: ['serving_default']
# INFO	2018-12-27 15:37:22 +0530	master-replica-0		Signatures INCLUDED in export for Train: None
# INFO	2018-12-27 15:37:22 +0530	master-replica-0		Restoring parameters from gs://cloud-ml-job-bucket/model.ckpt-1000
# INFO	2018-12-27 15:37:22 +0530	master-replica-0		Assets added to graph.
# INFO	2018-12-27 15:37:22 +0530	master-replica-0		No assets to write.
# INFO	2018-12-27 15:37:25 +0530	master-replica-0		SavedModel written to: gs://cloud-ml-job-bucket/export/exporter/temp-1545905241/saved_model.pb
# INFO	2018-12-27 15:37:26 +0530	master-replica-0		global_step/sec: 8.26739
# INFO	2018-12-27 15:37:26 +0530	master-replica-0		loss = 0.16630419, step = 1001 (12.096 sec)
# INFO	2018-12-27 15:37:27 +0530	master-replica-0		global_step/sec: 61.1008
# INFO	2018-12-27 15:37:27 +0530	master-replica-0		loss = 0.15455255, step = 1101 (1.637 sec)
# INFO	2018-12-27 15:37:29 +0530	master-replica-0		global_step/sec: 76.8024
# INFO	2018-12-27 15:37:29 +0530	master-replica-0		loss = 0.21367037, step = 1201 (1.302 sec)
# INFO	2018-12-27 15:37:30 +0530	master-replica-0		global_step/sec: 63.9891
# INFO	2018-12-27 15:37:30 +0530	master-replica-0		loss = 0.17794038, step = 1301 (1.567 sec)
# INFO	2018-12-27 15:37:32 +0530	master-replica-0		global_step/sec: 62.9715
# INFO	2018-12-27 15:37:32 +0530	master-replica-0		loss = 0.2486634, step = 1401 (1.584 sec)
# INFO	2018-12-27 15:37:33 +0530	master-replica-0		Saving checkpoints for 1500 into gs://cloud-ml-job-bucket/model.ckpt.
# INFO	2018-12-27 15:37:36 +0530	master-replica-0		Calling model_fn.
# INFO	2018-12-27 15:37:37 +0530	master-replica-0		Done calling model_fn.
# INFO	2018-12-27 15:37:37 +0530	master-replica-0		Starting evaluation at 2018-12-27-10:07:37
# INFO	2018-12-27 15:37:37 +0530	master-replica-0		Graph was finalized.
# INFO	2018-12-27 15:37:37 +0530	master-replica-0		Restoring parameters from gs://cloud-ml-job-bucket/model.ckpt-1500
# INFO	2018-12-27 15:37:37 +0530	master-replica-0		Running local_init_op.
# INFO	2018-12-27 15:37:37 +0530	master-replica-0		Done running local_init_op.
# INFO	2018-12-27 15:37:37 +0530	master-replica-0		Finished evaluation at 2018-12-27-10:07:37
# INFO	2018-12-27 15:37:37 +0530	master-replica-0		Saving dict for global step 1500: global_step = 1500, loss = 0.1984755, mse = 1.9340057
# INFO	2018-12-27 15:37:38 +0530	master-replica-0		Saving 'checkpoint_path' summary for global step 1500: gs://cloud-ml-job-bucket/model.ckpt-1500
# INFO	2018-12-27 15:37:39 +0530	master-replica-0		Calling model_fn.
# INFO	2018-12-27 15:37:39 +0530	master-replica-0		Done calling model_fn.
# INFO	2018-12-27 15:37:39 +0530	master-replica-0		Signatures INCLUDED in export for Eval: None
# INFO	2018-12-27 15:37:39 +0530	master-replica-0		Signatures INCLUDED in export for Classify: None
# INFO	2018-12-27 15:37:39 +0530	master-replica-0		Signatures INCLUDED in export for Regress: None
# INFO	2018-12-27 15:37:39 +0530	master-replica-0		Signatures INCLUDED in export for Predict: ['serving_default']
# INFO	2018-12-27 15:37:39 +0530	master-replica-0		Signatures INCLUDED in export for Train: None
# INFO	2018-12-27 15:37:39 +0530	master-replica-0		Restoring parameters from gs://cloud-ml-job-bucket/model.ckpt-1500
# INFO	2018-12-27 15:37:39 +0530	master-replica-0		Assets added to graph.
# INFO	2018-12-27 15:37:39 +0530	master-replica-0		No assets to write.
# INFO	2018-12-27 15:37:42 +0530	master-replica-0		SavedModel written to: gs://cloud-ml-job-bucket/export/exporter/temp-1545905258/saved_model.pb
# INFO	2018-12-27 15:37:43 +0530	master-replica-0		global_step/sec: 9.06602
# INFO	2018-12-27 15:37:43 +0530	master-replica-0		loss = 0.18469572, step = 1501 (11.030 sec)
# INFO	2018-12-27 15:37:44 +0530	master-replica-0		global_step/sec: 83.6092
# INFO	2018-12-27 15:37:44 +0530	master-replica-0		loss = 0.17269024, step = 1601 (1.197 sec)
# INFO	2018-12-27 15:37:45 +0530	master-replica-0		global_step/sec: 67.132
# INFO	2018-12-27 15:37:45 +0530	master-replica-0		loss = 0.18099952, step = 1701 (1.489 sec)
# INFO	2018-12-27 15:37:47 +0530	master-replica-0		global_step/sec: 72.6496
# INFO	2018-12-27 15:37:47 +0530	master-replica-0		loss = 0.20121437, step = 1801 (1.376 sec)
# INFO	2018-12-27 15:37:48 +0530	master-replica-0		global_step/sec: 87.0498
# INFO	2018-12-27 15:37:48 +0530	master-replica-0		loss = 0.1633294, step = 1901 (1.149 sec)
# INFO	2018-12-27 15:37:49 +0530	master-replica-0		Saving checkpoints for 2000 into gs://cloud-ml-job-bucket/model.ckpt.
# INFO	2018-12-27 15:37:53 +0530	master-replica-0		Calling model_fn.
# INFO	2018-12-27 15:37:53 +0530	master-replica-0		Done calling model_fn.
# INFO	2018-12-27 15:37:53 +0530	master-replica-0		Starting evaluation at 2018-12-27-10:07:53
# INFO	2018-12-27 15:37:54 +0530	master-replica-0		Graph was finalized.
# INFO	2018-12-27 15:37:54 +0530	master-replica-0		Restoring parameters from gs://cloud-ml-job-bucket/model.ckpt-2000
# INFO	2018-12-27 15:37:54 +0530	master-replica-0		Running local_init_op.
# INFO	2018-12-27 15:37:54 +0530	master-replica-0		Done running local_init_op.
# INFO	2018-12-27 15:37:54 +0530	master-replica-0		Finished evaluation at 2018-12-27-10:07:54
# INFO	2018-12-27 15:37:54 +0530	master-replica-0		Saving dict for global step 2000: global_step = 2000, loss = 0.1984755, mse = 1.9340057
# INFO	2018-12-27 15:37:55 +0530	master-replica-0		Saving 'checkpoint_path' summary for global step 2000: gs://cloud-ml-job-bucket/model.ckpt-2000
# INFO	2018-12-27 15:37:55 +0530	master-replica-0		Calling model_fn.
# INFO	2018-12-27 15:37:56 +0530	master-replica-0		Done calling model_fn.
# INFO	2018-12-27 15:37:56 +0530	master-replica-0		Signatures INCLUDED in export for Eval: None
# INFO	2018-12-27 15:37:56 +0530	master-replica-0		Signatures INCLUDED in export for Classify: None
# INFO	2018-12-27 15:37:56 +0530	master-replica-0		Signatures INCLUDED in export for Regress: None
# INFO	2018-12-27 15:37:56 +0530	master-replica-0		Signatures INCLUDED in export for Predict: ['serving_default']
# INFO	2018-12-27 15:37:56 +0530	master-replica-0		Signatures INCLUDED in export for Train: None
# INFO	2018-12-27 15:37:56 +0530	master-replica-0		Restoring parameters from gs://cloud-ml-job-bucket/model.ckpt
into gs://cloud-ml-job-bucket/model.ckpt.
# INFO	2018-12-27 15:38:27 +0530	master-replica-0		Calling model_fn.
# INFO	2018-12-27 15:38:27 +0530	master-replica-0		Done calling model_fn.
# INFO	2018-12-27 15:38:27 +0530	master-replica-0		Starting evaluation at 2018-12-27-10:08:27
# INFO	2018-12-27 15:38:27 +0530	master-replica-0		Graph was finalized.
# INFO	2018-12-27 15:38:27 +0530	master-replica-0		Restoring parameters from gs://cloud-ml-job-bucket/model.ckpt-3000
# INFO	2018-12-27 15:38:28 +0530	master-replica-0		Running local_init_op.
# INFO	2018-12-27 15:38:28 +0530	master-replica-0		Done running local_init_op.
# INFO	2018-12-27 15:38:28 +0530	master-replica-0		Finished evaluation at 2018-12-27-10:08:28
# INFO	2018-12-27 15:38:28 +0530	master-replica-0		Saving dict for global step 3000: global_step = 3000, loss = 0.1984755, mse = 1.9340057
# INFO	2018-12-27 15:38:28 +0530	master-replica-0		Saving 'checkpoint_path' summary for global step 3000: gs://cloud-ml-job-bucket/model.ckpt-3000
# INFO	2018-12-27 15:38:29 +0530	master-replica-0		Calling model_fn.
# INFO	2018-12-27 15:38:29 +0530	master-replica-0		Done calling model_fn.
# INFO	2018-12-27 15:38:29 +0530	master-replica-0		Signatures INCLUDED in export for Eval: None
# INFO	2018-12-27 15:38:29 +0530	master-replica-0		Signatures INCLUDED in export for Classify: None
# INFO	2018-12-27 15:38:29 +0530	master-replica-0		Signatures INCLUDED in export for Regress: None
# INFO	2018-12-27 15:38:29 +0530	master-replica-0		Signatures INCLUDED in export for Predict: ['serving_default']
# INFO	2018-12-27 15:38:29 +0530	master-replica-0		Signatures INCLUDED in export for Train: None
# INFO	2018-12-27 15:38:29 +0530	master-replica-0		Restoring parameters from gs://cloud-ml-job-bucket/model.ckpt-3000
# INFO	2018-12-27 15:38:29 +0530	master-replica-0		Assets added to graph.
# INFO	2018-12-27 15:38:29 +0530	master-replica-0		No assets to write.
# INFO	2018-12-27 15:38:32 +0530	master-replica-0		SavedModel written to: gs://cloud-ml-job-bucket/export/exporter/temp-1545905309/saved_model.pb
# INFO	2018-12-27 15:38:33 +0530	master-replica-0		global_step/sec: 8.76944
# INFO	2018-12-27 15:38:33 +0530	master-replica-0		loss = 0.20416299, step = 3001 (11.403 sec)
# INFO	2018-12-27 15:38:35 +0530	master-replica-0		global_step/sec: 73.6698
# INFO	2018-12-27 15:38:35 +0530	master-replica-0		loss = 0.15987322, step = 3101 (1.357 sec)
# INFO	2018-12-27 15:38:36 +0530	master-replica-0		global_step/sec: 72.1795
# INFO	2018-12-27 15:38:36 +0530	master-replica-0		loss = 0.16844097, step = 3201 (1.385 sec)
# INFO	2018-12-27 15:38:37 +0530	master-replica-0		global_step/sec: 88.0816
# INFO	2018-12-27 15:38:37 +0530	master-replica-0		loss = 0.25695705, step = 3301 (1.135 sec)
# INFO	2018-12-27 15:38:38 +0530	master-replica-0		global_step/sec: 77.434
# INFO	2018-12-27 15:38:38 +0530	master-replica-0		loss = 0.29215527, step = 3401 (1.292 sec)
# INFO	2018-12-27 15:38:40 +0530	master-replica-0		Saving checkpoints for 3500 into gs://cloud-ml-job-bucket/model.ckpt.
# INFO	2018-12-27 15:38:44 +0530	master-replica-0		Calling model_fn.
# INFO	2018-12-27 15:38:44 +0530	master-replica-0		Done calling model_fn.
# INFO	2018-12-27 15:38:44 +0530	master-replica-0		Starting evaluation at 2018-12-27-10:08:44
# INFO	2018-12-27 15:38:44 +0530	master-replica-0		Graph was finalized.
# INFO	2018-12-27 15:38:44 +0530	master-replica-0		Restoring parameters from gs://cloud-ml-job-bucket/model.ckpt-3500
# INFO	2018-12-27 15:38:45 +0530	master-replica-0		Running local_init_op.
# INFO	2018-12-27 15:38:45 +0530	master-replica-0		Done running local_init_op.
# INFO	2018-12-27 15:38:45 +0530	master-replica-0		Finished evaluation at 2018-12-27-10:08:45
# INFO	2018-12-27 15:38:45 +0530	master-replica-0		Saving dict for global step 3500: global_step = 3500, loss = 0.1984755, mse = 1.9340057
# INFO	2018-12-27 15:38:45 +0530	master-replica-0		Saving 'checkpoint_path' summary for global step 3500: gs://cloud-ml-job-bucket/model.ckpt-3500
# INFO	2018-12-27 15:38:47 +0530	master-replica-0		Calling model_fn.
# INFO	2018-12-27 15
# INFO	2018-12-27 15:39:09 +0530	master-replica-0		global_step/sec: 73.3751
# INFO	2018-12-27 15:39:09 +0530	master-replica-0		loss = 0.154282, step = 4101 (1.363 sec)
# INFO	2018-12-27 15:39:11 +0530	master-replica-0		global_step/sec: 86.5699
# INFO	2018-12-27 15:39:11 +0530	master-replica-0		loss = 0.23597988, step = 4201 (1.155 sec)
# INFO	2018-12-27 15:39:12 +0530	master-replica-0		global_step/sec: 74.0976
# INFO	2018-12-27 15:39:12 +0530	master-replica-0		loss = 0.25615594, step = 4301 (1.350 sec)
# INFO	2018-12-27 15:39:13 +0530	master-replica-0		global_step/sec: 67.7736
# INFO	2018-12-27 15:39:13 +0530	master-replica-0		loss = 0.27416074, step = 4401 (1.476 sec)
# INFO	2018-12-27 15:39:15 +0530	master-replica-0		Saving checkpoints for 4500 into gs://cloud-ml-job-bucket/model.ckpt.
# INFO	2018-12-27 15:39:18 +0530	master-replica-0		Calling model_fn.
# INFO	2018-12-27 15:39:18 +0530	master-replica-0		Done calling model_fn.
# INFO	2018-12-27 15:39:18 +0530	master-replica-0		Starting evaluation at 2018-12-27-10:09:18
# INFO	2018-12-27 15:39:19 +0530	master-replica-0		Graph was finalized.
# INFO	2018-12-27 15:39:19 +0530	master-replica-0		Restoring parameters from gs://cloud-ml-job-bucket/model.ckpt-4500
# INFO	2018-12-27 15:39:19 +0530	master-replica-0		Running local_init_op.
# INFO	2018-12-27 15:39:19 +0530	master-replica-0		Done running local_init_op.
# INFO	2018-12-27 15:39:19 +0530	master-replica-0		Finished evaluation at 2018-12-27-10:09:19
# INFO	2018-12-27 15:39:19 +0530	master-replica-0		Saving dict for global step 4500: global_step = 4500, loss = 0.1984755, mse = 1.9340057
# INFO	2018-12-27 15:39:20 +0530	master-replica-0		Saving 'checkpoint_path' summary for global step 4500: gs://cloud-ml-job-bucket/model.ckpt-4500
# INFO	2018-12-27 15:39:20 +0530	master-replica-0		Calling model_fn.
# INFO	2018-12-27 15:39:20 +0530	master-replica-0		Done calling model_fn.
# INFO	2018-12-27 15:39:20 +0530	master-replica-0		Signatures INCLUDED in export for Eval: None
# INFO	2018-12-27 15:39:20 +0530	master-replica-0		Signatures INCLUDED in export for Classify: None
# INFO	2018-12-27 15:39:20 +0530	master-replica-0		Signatures INCLUDED in export for Regress: None
# INFO	2018-12-27 15:39:20 +0530	master-replica-0		Signatures INCLUDED in export for Predict: ['serving_default']
# INFO	2018-12-27 15:39:20 +0530	master-replica-0		Signatures INCLUDED in export for Train: None
# INFO	2018-12-27 15:39:21 +0530	master-replica-0		Restoring parameters from gs://cloud-ml-job-bucket/model.ckpt-4500
# INFO	2018-12-27 15:39:21 +0530	master-replica-0		Assets added to graph.
# INFO	2018-12-27 15:39:21 +0530	master-replica-0		No assets to write.
# INFO	2018-12-27 15:39:23 +0530	master-replica-0		SavedModel written to: gs://cloud-ml-job-bucket/export/exporter/temp-1545905360/saved_model.pb
# INFO	2018-12-27 15:39:24 +0530	master-replica-0		global_step/sec: 9.0518
# INFO	2018-12-27 15:39:24 +0530	master-replica-0		loss = 0.17658341, step = 4501 (11.048 sec)
# INFO	2018-12-27 15:39:25 +0530	master-replica-0		Saving checkpoints for 4562 into gs://cloud-ml-job-bucket/model.ckpt.
# INFO	2018-12-27 15:39:29 +0530	master-replica-0		Calling model_fn.
# INFO	2018-12-27 15:39:29 +0530	master-replica-0		Done calling model_fn.
# INFO	2018-12-27 15:39:29 +0530	master-replica-0		Starting evaluation at 2018-12-27-10:09:29
# INFO	2018-12-27 15:39:29 +0530	master-replica-0		Graph was finalized.
# INFO	2018-12-27 15:39:29 +0530	master-replica-0		Restoring parameters from gs://cloud-ml-job-bucket/model.ckpt-4562
# INFO	2018-12-27 15:39:30 +0530	master-replica-0		Running local_init_op.
# INFO	2018-12-27 15:39:30 +0530	master-replica-0		Done running local_init_op.
# INFO	2018-12-27 15:39:30 +0530	master-replica-0		Finished evaluation at 2018-12-27-10:09:30
# INFO	2018-12-27 15:39:30 +0530	master-replica-0		Saving dict for global step 4562: global_step = 4562, loss = 0.1984755, mse = 1.9340057
# INFO	2018-12-27 15:39:30 +0530	master-replica-0		Saving 'checkpoint_path' summary for global step 4562: gs://cloud-ml-job-bucket/model.ckpt-4562
# INFO	2018-12-27 15:39:31 +0530	master-replica-0		Calling model_fn.
# INFO	2018-12-27 15:39:31 +0530	master-replica-0		Done calling model_fn.
# INFO	2018-12-27 15:39:31 +0530	master-replica-0		Signatures INCLUDED in export for Eval: None
# INFO	2018-12-27 15:39:31 +0530	master-replica-0		Signatures INCLUDED in export for Classify: None
# INFO	2018-12-27 15:39:31 +0530	master-replica-0		Signatures INCLUDED in export for Regress: None
# INFO	2018-12-27 15:39:31 +0530	master-replica-0		Signatures INCLUDED in export for Predict: ['serving_default']
# INFO	2018-12-27 15:39:31 +0530	master-replica-0		Signatures INCLUDED in export for Train: None
# INFO	2018-12-27 15:39:31 +0530	master-replica-0		Restoring parameters from gs://cloud-ml-job-bucket/model.ckpt-4562
# INFO	2018-12-27 15:39:31 +0530	master-replica-0		Assets added to graph.
# INFO	2018-12-27 15:39:31 +0530	master-replica-0		No assets to write.
# INFO	2018-12-27 15:39:34 +0530	master-replica-0		SavedModel written to: gs://cloud-ml-job-bucket/export/exporter/temp-1545905371/saved_model.pb
# INFO	2018-12-27 15:39:36 +0530	master-replica-0		Loss for final step: 0.17617127.
# INFO	2018-12-27 15:39:36 +0530	master-replica-0		Module completed; cleaning up.
# INFO	2018-12-27 15:39:36 +0530	master-replica-0		Clean up finished.
# INFO	2018-12-27 15:39:36 +0530	master-replica-0		Task completed successfully.
# endTime: '2018-12-27T15:44:09'
# jobId: housing_job_3
# startTime: '2018-12-27T15:35:53'
# state: SUCCEEDED

# %% [markdown]
# After the job is finished, it will create a folder in the bucket with the name JOB_DIR we specified above which will contain the same files and folders that were created when we ran the model locally.

# %% [markdown]
# ## Part 2 --> Deploying the trained model
#
# ### Step 1 --> creating the model

# %%
# %env MODEL_NAME kaggle_housing_price_prediction
# %env MODEL_PATH gs://cloud-ml-job-bucket/export/exporter/1545905371

#CREATE MODEL
# !gcloud ml-engine models create $MODEL_NAME
# Out:
# env: MODEL_NAME=kaggle_housing_price_prediction
# env: MODEL_PATH=gs://cloud-ml-job-bucket/export/exporter/1545905371
# WARNING: `--regions` flag will soon be required. Please explicitly specify a region. Using [us-central1] by default.
# Created ml engine model [projects/searce-sandbox/models/kaggle_housing_price_prediction].

# %% [markdown]
# ### Step 2 --> creating version for the model you just created

# %%
# !gcloud ml-engine versions create "version_1" --model $MODEL_NAME --origin $MODEL_PATH
# Out:
# Creating version (this might take a few minutes)......done.

# %% [markdown]
# ## Part 3 --> Serving the model for predictions
# The model expects a json input. So let us create that first.

# %%
#take a sample and save it to a json file
with open('test_data.json', 'w') as outfile:
  json.dump(list(X[35]), outfile)

# %%
#gcloud command to make predictions through the model we just deployed.
# !gcloud ml-engine predict --model kaggle_housing_price_prediction --version version_1 --json-instances test_data.json
# Out:
# DENSE_3
# [-1.0]

# %%
#perform inverse transform to get the actual price. 
#You can add this step in the model.py file itself by defining an output_fn() which will take the 
#prediction outputs from the model and will perform this step for you.
sc_y.inverse_transform([-1.0])
# Out:
# array([101505.90400434])

# %% [markdown]
# ### This is how you can use Google Cloud ML-Engine to create, deploy and serve your own model on your own dataset.
